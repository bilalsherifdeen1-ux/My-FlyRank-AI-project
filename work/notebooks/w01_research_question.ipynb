# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
"""
Freestyle: I want to predict which pages are likely to decline in the next
90 days based on early signals (CTR drop, position slippage, content age),
so that SEO teams can prioritize content refreshes before traffic loss
becomes severe, rather than reacting after the fact.
"""
# Out:
# '\nFreestyle: I want to predict which pages are likely to decline in the next \n90 days based on early signals (CTR drop, position slippage, content age), \nso that SEO teams can prioritize content refreshes before traffic loss \nbecomes severe, rather than reacting after the fact.\n'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
"""
Decision: which pages should be scheduled for a content refresh this month?
Action: a content team member reviews the flagged pages and updates them.
Cost of a wrong call: flagging a healthy page wastes writer time; missing
a declining page means continued traffic loss that compounds over months.
"""
# Out:
# '\nDecision: which pages should be scheduled for a content refresh this month?\nAction: a content team member reviews the flagged pages and updates them.\nCost of a wrong call: flagging a healthy page wastes writer time; missing \na declining page means continued traffic loss that compounds over months.\n'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import subprocess, os
subprocess.run(["git", "clone", "https://github.com/bilalsherifdeen1-ux/My-FlyRank-AI-project.git"])
os.chdir("My-FlyRank-AI-project")
print("Now in:", os.getcwd())
# Out:
# Now in: /content/My-FlyRank-AI-project/My-FlyRank-AI-project

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
"""
This work is observed and directional, not causal. I can say which pages
show declining patterns and which features correlate with that decline.
I cannot claim to predict Google's algorithm, guarantee traffic recovery,
or prove causation between any single feature and ranking changes.
"""
# Out:
# "\nThis work is observed and directional, not causal. I can say which pages \nshow declining patterns and which features correlate with that decline. \nI cannot claim to predict Google's algorithm, guarantee traffic recovery, \nor prove causation between any single feature and ranking changes.\n"

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
